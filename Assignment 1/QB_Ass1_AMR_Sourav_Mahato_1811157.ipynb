# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
# entries of the matrix
diag_odd = 250
diag_even = 185
off_diag = 50
n = 50

# %%
# Varing(increasing) the off diagonal values keeping other parameters constant
print("\n ---############ Varing(increasing) the off diagonal values keeping other parameters constant#########---")
while off_diag <= 150:
    print("\n\n #############For Beta =",off_diag,"###################")
    # n*n matrix
    M = np.zeros((n,n))

    # creating the matrix
    for i in range(n):
        for j in range(n):
            if i == j:
                if i%2 == 0:
                    M[i][j] = diag_even
                elif i%2 != 0:
                    M[i][j] = diag_odd
            elif i+1 == j or i-1 == j:
                M[i][j] = off_diag
            
    print("\n---------The Matrix is-------")
    print(M)

    # Eigenvalue and Eigenvector calculation
    e_values, e_vectors = np.linalg.eig(M)
    print("\n-----Eigenvalues of the matrix is-----")
    print(e_values)
    
    # sorting the eigenvalues min to max
    e_values.sort()
    # plotting the eigenvalues
    d = e_values[n-1]-e_values[0]
    width = d/n
    
    plt.hist(e_values, bins = n)
    print("\n-----Plot of Density of eigen states-----")
    print("Width of each bar =", width)
    plt.show()
    off_diag = off_diag + 20
# Out:
#  ---############ Varing(increasing) the off diagonal values keeping other parameters constant#########---
#
#
#  #############For Beta = 50 ###################
#
# ---------The Matrix is-------
# [[185.  50.   0. ...   0.   0.   0.]
#  [ 50. 250.  50. ...   0.   0.   0.]
#  [  0.  50. 185. ...   0.   0.   0.]
#  ...
#  [  0.   0.   0. ... 250.  50.   0.]
#  [  0.   0.   0. ...  50. 185.  50.]
#  [  0.   0.   0. ...   0.  50. 250.]]
#
# -----Eigenvalues of the matrix is-----
# [112.5316593  113.07186835 113.96927438 115.21944969 116.81616534
#  118.75135654 121.01507112 123.59539487 126.47834445 129.6477149
#  133.08486264 136.76839654 140.67373687 144.77248302 149.03150323
#  153.41161858 157.86569779 162.33591007 166.74982492 171.0150871
#  175.01277461 178.59082832 181.56199786 184.85442823 183.71561749
#  322.4683407  321.92813165 321.03072562 319.78055031 318.18383466
#  316.24864346 313.98492888 311.40460513 308.52165555 305.3522851
# ...

# %%
# Varing(increasing) the N values keeping other parameters constant
print("\n ---############ Varing(increasing) the N values keeping other parameters constant #########---")
off_diag = 50
while n <= 550 :
    print("\n\n #############For N =",n,"###################")
    # n*n matrix
    M = np.zeros((n,n))

    # creating the matrix
    for i in range(n):
        for j in range(n):
            if i == j:
                if i%2 == 0:
                    M[i][j] = diag_even
                elif i%2 != 0:
                    M[i][j] = diag_odd
            elif i+1 == j or i-1 == j:
                M[i][j] = off_diag
            
    print("\n---------The Matrix is-------")
    print(M)

    # Eigenvalue and Eigenvector calculation
    e_values, e_vectors = np.linalg.eig(M)
    print("\n-----Eigenvalues of the matrix is-----")
    print(e_values)
    
    # sorting the eigenvalues min to max
    e_values.sort()
    # plotting the eigenvalues
    d = e_values[n-1]-e_values[0]
    width = d/n
    
    plt.hist(e_values, bins = n)
    print("\n-----Plot of Density of eigen states-----")
    print("Width of each bar =", width)
    plt.show()
    n = n + 100
# Out:
#  ---############ Varing(increasing) the N values keeping other parameters constant #########---
#
#
#  #############For N = 50 ###################
#
# ---------The Matrix is-------
# [[185.  50.   0. ...   0.   0.   0.]
#  [ 50. 250.  50. ...   0.   0.   0.]
#  [  0.  50. 185. ...   0.   0.   0.]
#  ...
#  [  0.   0.   0. ... 250.  50.   0.]
#  [  0.   0.   0. ...  50. 185.  50.]
#  [  0.   0.   0. ...   0.  50. 250.]]
#
# -----Eigenvalues of the matrix is-----
# [112.5316593  113.07186835 113.96927438 115.21944969 116.81616534
#  118.75135654 121.01507112 123.59539487 126.47834445 129.6477149
#  133.08486264 136.76839654 140.67373687 144.77248302 149.03150323
#  153.41161858 157.86569779 162.33591007 166.74982492 171.0150871
#  175.01277461 178.59082832 181.56199786 184.85442823 183.71561749
#  322.4683407  321.92813165 321.03072562 319.78055031 318.18383466
#  316.24864346 313.98492888 311.40460513 308.52165555 305.3522851
# ...
